# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\sm315\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: beautifulsoup4==4.6.0 in c:\users\sm315\anaconda3\lib\site-packages (from konlpy) (4.6.0)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\sm315\anaconda3\lib\site-packages (from konlpy) (4.6.1)
# Requirement already satisfied: numpy>=1.6 in c:\users\sm315\anaconda3\lib\site-packages (from konlpy) (1.19.2)
# Requirement already satisfied: colorama in c:\users\sm315\anaconda3\lib\site-packages (from konlpy) (0.4.4)
# Requirement already satisfied: tweepy>=3.7.0 in c:\users\sm315\anaconda3\lib\site-packages (from konlpy) (3.10.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\sm315\anaconda3\lib\site-packages (from konlpy) (1.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sm315\anaconda3\lib\site-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\sm315\anaconda3\lib\site-packages (from tweepy>=3.7.0->konlpy) (2.24.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\sm315\anaconda3\lib\site-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sm315\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sm315\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\sm315\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sm315\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\sm315\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\sm315\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
f1 = open('/Users/SM315/Project/test_speak1.txt','r',encoding='euc-kr')
txt = f1.read()
f1.close()
txt
# Out:
# '어 먼저 그 아르바이트를 통해서 제가 그 어 일을 하긴 했지만 많은 관객들을 직접 만나봤습니다 그래서\n그 지속적으로 1학년때부터 4학년때까지 해온거기 때문에 그 기간동안 관객들에 대한 트랜드를 조사할 수 있었고\n또 그 뮤지컬이나 그 공연 시상에 대해서 그 간접적으로 배울 수 있었습니다.'

# %%
rs = okt.pos(txt)
rs
# Out:
# [('어', 'Eomi'),
#  ('먼저', 'Noun'),
#  ('그', 'Noun'),
#  ('아르바이트', 'Noun'),
#  ('를', 'Josa'),
#  ('통해', 'Noun'),
#  ('서', 'Josa'),
#  ('제', 'Noun'),
#  ('가', 'Josa'),
#  ('그', 'Noun'),
#  ('어', 'Eomi'),
#  ('일', 'Noun'),
#  ('을', 'Josa'),
#  ('하긴', 'Verb'),
#  ('했지만', 'Verb'),
#  ('많은', 'Adjective'),
#  ('관객', 'Noun'),
#  ('들', 'Suffix'),
#  ('을', 'Josa'),
#  ('직접', 'Noun'),
#  ('만나', 'Verb'),
#  ('봤습니다', 'Verb'),
#  ('그래서', 'Adverb'),
#  ('\n', 'Foreign'),
#  ('그', 'Noun'),
#  ('지속', 'Noun'),
#  ('적', 'Suffix'),
#  ('으로', 'Josa'),
#  ('1', 'Number'),
#  ('학년', 'Noun'),
#  ('때', 'Noun'),
#  ('부터', 'Josa'),
#  ('4', 'Number'),
#  ('학년', 'Noun'),
#  ('때', 'Noun'),
#  ('까지', 'Josa'),
#  ('해온거기', 'Verb'),
#  ('때문', 'Noun'),
#  ('에', 'Josa'),
#  ('그', 'Noun'),
#  ('기간', 'Noun'),
#  ('동안', 'Noun'),
#  ('관객', 'Noun'),
#  ('들', 'Suffix'),
#  ('에', 'Josa'),
#  ('대한', 'Noun'),
#  ('트랜드', 'Noun'),
#  ('를', 'Josa'),
#  ('조사', 'Noun'),
#  ('할', 'Verb'),
#  ('수', 'Noun'),
#  ('있었고', 'Adjective'),
#  ('\n', 'Foreign'),
#  ('또', 'Noun'),
#  ('그', 'Noun'),
#  ('뮤지컬', 'Noun'),
#  ('이나', 'Josa'),
#  ('그', 'Noun'),
#  ('공연', 'Noun'),
#  ('시상', 'Noun'),
#  ('에', 'Josa'),
#  ('대해', 'Noun'),
#  ('서', 'Josa'),
#  ('그', 'Noun'),
#  ('간접', 'Noun'),
#  ('적', 'Suffix'),
#  ('으로', 'Josa'),
#  ('배울', 'Verb'),
#  ('수', 'Noun'),
#  ('있었습니다', 'Adjective'),
#  ('.', 'Punctuation')]

# %%
df = pd.DataFrame(rs)
df
# Out:
#         0            1
# 0       어         Eomi
# 1      먼저         Noun
# 2       그         Noun
# 3   아르바이트         Noun
# 4       를         Josa
# ..    ...          ...
# 66     으로         Josa
# 67     배울         Verb
# 68      수         Noun
# 69  있었습니다    Adjective
# 70      .  Punctuation
#
# [71 rows x 2 columns]

# %%
Noun_df = df[(df[1] == 'Noun')]
Noun_df
# Out:
#         0     1
# 1      먼저  Noun
# 2       그  Noun
# 3   아르바이트  Noun
# 5      통해  Noun
# 7       제  Noun
# 9       그  Noun
# 11      일  Noun
# 16     관객  Noun
# 19     직접  Noun
# 24      그  Noun
# 25     지속  Noun
# 29     학년  Noun
# 30      때  Noun
# 33     학년  Noun
# 34      때  Noun
# 37     때문  Noun
# 39      그  Noun
# 40     기간  Noun
# 41     동안  Noun
# 42     관객  Noun
# 45     대한  Noun
# 46    트랜드  Noun
# 48     조사  Noun
# 50      수  Noun
# 53      또  Noun
# 54      그  Noun
# 55    뮤지컬  Noun
# 57      그  Noun
# 58     공연  Noun
# 59     시상  Noun
# 61     대해  Noun
# 63      그  Noun
# 64     간접  Noun
# 68      수  Noun

# %%
Noun_df.drop(1, axis = 1, inplace=True)
Noun_df
# Out:
# C:\Users\SM315\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#         0
# 1      먼저
# 2       그
# 3   아르바이트
# 5      통해
# 7       제
# 9       그
# 11      일
# 16     관객
# 19     직접
# 24      그
# 25     지속
# 29     학년
# 30      때
# 33     학년
# 34      때
# 37     때문
# 39      그
# 40     기간
# 41     동안
# 42     관객
# 45     대한
# 46    트랜드
# 48     조사
# 50      수
# 53      또
# 54      그
# 55    뮤지컬
# 57      그
# 58     공연
# 59     시상
# 61     대해
# 63      그
# 64     간접
# 68      수

# %%
pos_list=np.array(Noun_df[0].tolist())
pos_list
# Out:
# array(['먼저', '그', '아르바이트', '통해', '제', '그', '일', '관객', '직접', '그', '지속',
#        '학년', '때', '학년', '때', '때문', '그', '기간', '동안', '관객', '대한', '트랜드',
#        '조사', '수', '또', '그', '뮤지컬', '그', '공연', '시상', '대해', '그', '간접', '수'],
#       dtype='<U5')

# %%
def counter(pos_list):
  pos_count = {}
  for word in pos_list:
    if word in pos_count :
      pos_count[word] += 1
    else :
      pos_count[word] = 1
  return pos_count

pos_count = counter(pos_list)
pos_count
# Out:
# {'먼저': 1,
#  '그': 7,
#  '아르바이트': 1,
#  '통해': 1,
#  '제': 1,
#  '일': 1,
#  '관객': 2,
#  '직접': 1,
#  '지속': 1,
#  '학년': 2,
#  '때': 2,
#  '때문': 1,
#  '기간': 1,
#  '동안': 1,
#  '대한': 1,
#  '트랜드': 1,
#  '조사': 1,
#  '수': 2,
#  '또': 1,
#  '뮤지컬': 1,
#  '공연': 1,
#  '시상': 1,
#  '대해': 1,
#  '간접': 1}

# %%
# 정렬
pos_count = sorted(pos_count.items(), key = lambda x:x[1], reverse=True)
pos_count
# Out:
# [('그', 7),
#  ('관객', 2),
#  ('학년', 2),
#  ('때', 2),
#  ('수', 2),
#  ('먼저', 1),
#  ('아르바이트', 1),
#  ('통해', 1),
#  ('제', 1),
#  ('일', 1),
#  ('직접', 1),
#  ('지속', 1),
#  ('때문', 1),
#  ('기간', 1),
#  ('동안', 1),
#  ('대한', 1),
#  ('트랜드', 1),
#  ('조사', 1),
#  ('또', 1),
#  ('뮤지컬', 1),
#  ('공연', 1),
#  ('시상', 1),
#  ('대해', 1),
#  ('간접', 1)]

# %%
fields = ['단어' , '횟수']
rows = pos_count

# %%
import csv

# %%
with open(r'pos_test.csv', 'w', newline='\n') as f:
  write = csv.writer(f)
  write.writerow(fields)
  write.writerows(rows)

# %%
test_pos_word = pd.read_csv('/Users/SM315/Project/pos_test.csv', encoding='euc-kr')
test_pos_word
# Out:
#        단어  횟수
# 0       그   7
# 1      관객   2
# 2      학년   2
# 3       때   2
# 4       수   2
# 5      먼저   1
# 6   아르바이트   1
# 7      통해   1
# 8       제   1
# 9       일   1
# 10     직접   1
# 11     지속   1
# 12     때문   1
# 13     기간   1
# 14     동안   1
# 15     대한   1
# 16    트랜드   1
# 17     조사   1
# 18      또   1
# 19    뮤지컬   1
# 20     공연   1
# 21     시상   1
# 22     대해   1
# 23     간접   1

# %%
pos_data1 = test_pos_word[['단어']]
pos_data2 = test_pos_word[['횟수']]

# %%
posword = test_pos_word['단어'].dropna().values.tolist()[:6]
posword
# Out:
# ['그', '관객', '학년', '때', '수', '먼저']

# %%
posword_count = test_pos_word['횟수'].values.tolist()[:6]
posword_count
# Out:
# [7, 2, 2, 2, 2, 1]

# %%
x = np.arange(len(posword))
x
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
plt.figure(figsize=(10,5))
plt.rc('font', family='Malgun Gothic')
plt.xlim(-1,6)
plt.ylim(0,15)
plt.bar(posword, posword_count, width =0.5, color ='yellow',align='center')
plt.title('단어 빈도수 분석결과', fontsize = 20)
plt.xlabel('<단어 종류>', fontsize = 14)
plt.ylabel('<빈도수>', fontsize = 14)
plt.rc('xtick', labelsize = 12)
plt.rc('ytick', labelsize = 12)
#plt.rcParams['figure.figuresize'] = (10,4)
plt.grid(axis='y', linestyle='--', alpha = 0.5)

for i, v in enumerate(x):
    aa = "{:,}회".format(posword_count[i])
    plt.text(v,posword_count[i],aa,fontsize=9,color='#000000',
              horizontalalignment='center',verticalalignment='bottom')

plt.savefig('C://단어의 종류와 빈도수.png',bbox_inches='tight')
